# %%
import pandas as pd

# %%
dir = "/Users/afrizalmulyana/Library/CloudStorage/OneDrive-PTORBITVENTURAINODNESIA/Afrizal Meka/Project Pribadi/aplikasi-cek-nilai-posttest/database/database_apollo_class.xlsx"
df1 = pd.read_excel(dir, sheet_name="intro_ai")

# %%
df2 = pd.read_excel(dir, sheet_name="python")
df2 = df2.drop(['nama'], axis=1)

df3 = pd.read_excel(dir, sheet_name="siklus_ai")
df3 = df3.drop(['nama'], axis=1)

df4 = pd.read_excel(dir, sheet_name="intro_ml")
df4 = df4.drop(['nama'], axis=1)

df_final = pd.concat([df1, df2, df3, df4], axis=1)

# %%
df_final
# Out:
#                           nama  id_msib          nohp  nilai_intro_ai_1  \
# 0     Adi Mulya Hyoga Pramesta  3725349   81392079914               100
# 1             Ahmad Imam Khofi  3801595   89524253715               100
# 2        Ahmad Malikhul Khakim  3832337   85712555526               100
# 3            Bagus Rifqi Ridho  3763981   85161382552               100
# 4             Bima Aji Maulana  3852379   87714476866               100
# 5            Christopher Prima  3845534   82243039103               100
# 6           Dhiya Arwa Fadhila  3841158  895422462944               100
# 7                   Dinda Arum  3788761   82185511649               100
# 8          Dinda Regina Nofiar  3346764   85156045861               100
# 9                 Faishal Bahy  3447291   82260368898               100
# 10       Faqih Azka Ash-Shidqi  3841917   82118045113               100
# 11    Fiyandhika Ridho Pratama  3854585   82348877452               100
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 63 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nama               31 non-null     object
#  1   id_msib            31 non-null     int64
#  2   nohp               31 non-null     int64
#  3   nilai_intro_ai_1   31 non-null     int64
#  4   nilai_intro_ai_2   31 non-null     int64
#  5   nilai_intro_ai_3   31 non-null     int64
#  6   nilai_intro_ai_4   31 non-null     int64
#  7   nilai_intro_ai_5   31 non-null     int64
#  8   absen_intro_ai_1   31 non-null     int64
#  9   absen_intro_ai_2   31 non-null     object
#  10  absen_intro_ai_3   31 non-null     int64
#  11  absen_intro_ai_4   31 non-null     object
#  12  absen_intro_ai_5   31 non-null     object
#  13  posttest_intro_ai  31 non-null     int64
#  14  final_intro_ai     29 non-null     float64
#  15  alphabet_intro_ai  31 non-null     object
# ...

# %%
absen_intro_ai_1 = df['absen_intro_ai_1'][0]
absen_intro_ai_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 absen_intro_ai_1 = df['absen_intro_ai_1'][0]
#       2 absen_intro_ai_1
#
# NameError: name 'df' is not defined

# %%
status_absen = {1 : 'Hadir', 0 : 'Tidak Hadir', 'K' : 'Durasi Kurang'}

absen_intro_ai_1 = status_absen[absen_intro_ai_1]
absen_intro_ai_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 3>()
#       1 status_absen = {1 : 'Hadir', 0 : 'Tidak Hadir', 'K' : 'Durasi Kurang'}
# ----> 3 absen_intro_ai_1 = status_absen[absen_intro_ai_1]
#       4 absen_intro_ai_1
#
# NameError: name 'absen_intro_ai_1' is not defined

# %%
df['nama'] = df['nama'].str.lower()
df['univ'] = df['univ'].str.lower()
df['prodi'] = df['prodi'].str.lower()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 df['nama'] = df['nama'].str.lower()
#       2 df['univ'] = df['univ'].str.lower()
#       3 df['prodi'] = df['prodi'].str.lower()
#
# NameError: name 'df' is not defined

# %%
size = df.shape
size = size[0]
size
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 size = df.shape
#       2 size = size[0]
#       3 size
#
# NameError: name 'df' is not defined

# %%
input_nama = str(input("nama : ")).lower()

size = df.shape
size = size[0] - 1
ds = '0'
nlp = '0'
cv = '0'
tech = '0'

for data in df.index:
    name = df['nama'][data]
    
    if input_nama == name:
        ds.append(df['ds'][x])
        nlp.append(df['nlp'][x])
        cv.append(df['cv'][x])
        tech.append(df['tech'][x])
        break
    
    elif data == size:
        print("data tidak ditemukan")
        
print(ds)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 input_nama = str(input("nama : ")).lower()
#       3 size = df.shape
#       4 size = size[0] - 1
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    1071 if not self._allow_stdin:
#    1072     raise StdinNotImplementedError(
#    1073         "raw_input was called, but this frontend does not support input requests."
#    1074     )
# -> 1075 return self._input_request(
#    1076     str(prompt),
#    1077     self._parent_ident["shell"],
#    1078     self.get_parent("shell"),
#    1079     password=False,
#    1080 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py:1120, in Kernel._input_request(self, prompt, ident, parent, password)
#    1117             break
# ...

# %%
# Define a dictionary containing students data
data = {'Name': ['Ankit', 'Amit',
                 'Aishwarya', 'Priyanka'],
        'Age': [21, 19, 20, 18],
        'Stream': ['Math', 'Commerce',
                   'Arts', 'Biology'],
        'Percentage': [88, 92, 95, 70]}
  
# Convert the dictionary into DataFrame
df2 = pd.DataFrame(data, columns=['Name', 'Age', 
                                 'Stream', 'Percentage'])
  
print("Given Dataframe :\n", df2)
  
print("\nIterating over rows using index attribute :\n")
  
# iterate through each row and select
# 'Name' and 'Stream' column respectively.
for ind in df2.index:
    name = df2['Name'][ind]
    if name == 'Amit':
        print(df2['Name'][ind], df2['Stream'][ind])

# %%
pd.show_versions()

# %%
dir = "../database/database.xlsx"
df1 = pd.read_excel(dir, sheet_name="datasiswa")

df_nama = df1['nama']

# %%
df1
# Out:
#                               nama             nim  id_msib  \
# 0                      Ani Saputri   2010631030003  4845859
# 1              Anisa Sekar Pradita      7101420283  4522447
# 2               Arya Al Rian Yayat        43120048  4458277
# 3              Daffa Ammar Pratama       C1A020061  4718941
# 4               Elyza Dewi Fortuna       202053121  5094517
# 5                Fauzan Nur Cholis        21200084  5672734
# 6              Haidariyad Iskandar    A11202013185  5307156
# 7                   Hamidatul Ulfa       203020005  4446875
# 8         Ingwie Bintang Pramudyas        20SA3102  5473046
# 9            Muhamad Akhirul Sidik     20200910055  5549226
# 10              Nadiva Naifa Najla       202053225  4425468
# 11      Noor Syafa'ah Kusuma Putri       202053045  4423585
# 12                   Nuansa Bening        41200122  5498242
# 13  Raymundus Erik Chandra Yunanta        20530035  4489640
# 14                       Risdianti  11203462010023  5137392
# ...

# %%
df_nama
# Out:
# 0                        Ani Saputri
# 1                Anisa Sekar Pradita
# 2                 Arya Al Rian Yayat
# 3                Daffa Ammar Pratama
# 4                 Elyza Dewi Fortuna
# 5                  Fauzan Nur Cholis
# 6                Haidariyad Iskandar
# 7                     Hamidatul Ulfa
# 8           Ingwie Bintang Pramudyas
# 9              Muhamad Akhirul Sidik
# 10                Nadiva Naifa Najla
# 11        Noor Syafa'ah Kusuma Putri
# 12                     Nuansa Bening
# 13    Raymundus Erik Chandra Yunanta
# 14                         Risdianti
# 15             Rizki Arief Dehanudin
# 16                 Windi Puspitasari
# 17                          Yulianti
# 18                           Dummy 1
# 19                           Dummy 2
# Name: nama, dtype: object

# %%
df_nama = list(df_nama)

# %%
df_nama

# %%
#menentukan ukuran baris, sebagai penentu kapan berhenti dari loops
size = df1.shape
size = size[0] - 1

# %%
nama = "Ani Saputri"
nim = "2010631030003"
id_msib = 4845859
univ = "Universitas Singaperbangsa Karawang"
nohp = 83863024527

data = [nama, nim, id_msib, univ, nohp]

data

# %%
for x in df1.index:
    A = df1['nama'][x]
    B = df1['nim'][x]
    C = df1['id_msib'][x]
    D = df1['univ'][x]
    E = df1['nohp'][x]


    #memvalidasi apakah nama, id_msib, univ, prodi, nohp sesuai atau tidak
    if (data[0] == A) and (data[1] == B) and (data[2] == C) and (data[3] == D) and (data[4] == E):
        info = "Data tervalidasi"
        break

    elif x == size:
        info = "hasil tidak ditemukan"
        
print(info)

# %%
print(df1['nama'])
print(df1['nim'])
print(df1['id_msib'])
print(df1['univ'])
print(df1['nohp'])

# %%
print(type(nama))
print(type(nim))
print(type(id_msib))
print(type(univ))
print(type(nohp))

# %%
df1['univ'] = df1['univ'].str.lower()
df1['univ']
# Out:
# 0                   universitas singaperbangsa karawang
# 1                           universitas negeri semarang
# 2                       politeknik negeri ujung pandang
# 3                        universitas jenderal soedirman
# 4                               universitas muria kudus
# 5     universitas pembangunan nasional veteran yogya...
# 6                           universitas dian nuswantoro
# 7                                            stkip bima
# 8                         universitas amikom purwokerto
# 9                                  universitas kuningan
# 10                              universitas muria kudus
# 11                              universitas muria kudus
# 12                                   stmik ikmi cirebon
# 13                                stmik sinar nusantara
# 14                               universitas sari mulia
# 15                        universitas amikom purwokerto
# 16                   universitas sultan ageng tirtayasa
# ...

# %%
univ = input("univ :")
univ = univ.lower()
data = []
data.append(str(univ))

data
# Out:
# univ : Universitas Singaperbangsa Karawang
# ['universitas singaperbangsa karawang']

# %%
for x in df1.index:
    B = df1['univ'][x]


    #memvalidasi apakah nama, id_msib, univ, prodi, nohp sesuai atau tidak
    if data[0] == B:
        print("Data tervalidasi")
# Out:
# Data tervalidasi
